# %%
#Importing the required Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#to view all the columns and rows
pd.set_option('display.max_columns', None) 
pd.set_option('display.max_rows', None)

# %%
#Acquiring the dataset
df=pd.read_excel("customer_retention_dataset.xlsx")  #Reading the train data set
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
df.shape
# Out:
# (269, 71)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %%
df.describe(include='O')
# Out:
#        1Gender of respondent 2 How old are you?   \
# count                    269                 269
# unique                     2                   5
# top                   Female         31-40 years
# freq                     181                  81
#
#        3 Which city do you shop online from?  \
# count                                    269
# unique                                    11
# top                                    Delhi
# freq                                      58
#
#        5 Since How Long You are Shopping Online ?  \
# count                                         269
# unique                                          5
# top                                 Above 4 years
# freq                                           98
#
#        6 How many times you have made an online purchase in the past 1 year?  \
# count                                                 269
# unique                                                  6
# ...

# %%
df['4 What is the Pin Code of where you shop online from?'].value_counts()
# Out:
# 201308    38
# 132001    19
# 201310    18
# 110044    16
# 250001     9
# 173229     9
# 173212     9
# 560010     8
# 132036     8
# 122018     8
# 560037     8
# 110008     7
# 110011     7
# 201306     7
# 110014     6
# 110018     6
# 201305     5
# 201008     5
# 201009     5
# 201312     5
# 244001     5
# 530068     5
# 122009     4
# 201001     4
# 560003     4
# 201304     4
# 110009     4
# 201303     4
# 560002     4
# 560018     4
# 110042     4
# 110030     4
# 201005     4
# 110039     4
# 560013     3
# 203001     2
# 203202     1
# 560001     1
# 203207     1
# Name: 4 What is the Pin Code of where you shop online from?, dtype: int64

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df.columns=df.columns.str.replace('\t', '')
df.columns=df.columns.str.strip()
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you?',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?',
#        '10 What is the operating system (OS) of your device?',
#        '11 What browser do you run on your device to access the website?',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?',
#        '13 After first visit, how do you reach the online retail store?',
#        '14 How much time do you explore the e- retail store before making a purchase decision?',
#        '15 What is your preferred payment Option?',
# ...

# %%
df['1Gender of respondent'].value_counts()
# Out:
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64

# %%
sns.countplot(x=df['1Gender of respondent'], data=df)
# Out:
# <AxesSubplot:xlabel='1Gender of respondent', ylabel='count'>

# %%
sns.countplot(x=df['2 How old are you?'], hue=df['1Gender of respondent'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x=df['3 Which city do you shop online from?'])
plt.xticks(rotation=90)
plt.show()

# %%
location=pd.crosstab(df['4 What is the Pin Code of where you shop online from?'], df['3 Which city do you shop online from?'], margins=True)
location
# Out:
# 3 Which city do you shop online from?               Bangalore   Bulandshahr  \
# 4 What is the Pin Code of where you shop online...
# 110008                                                       0            0
# 110009                                                       0            0
# 110011                                                       0            0
# 110014                                                       0            0
# 110018                                                       0            0
# 110030                                                       0            0
# 110039                                                       0            0
# 110042                                                       0            0
# 110044                                                       0            0
# 122009                                                       0            0
# 122018                                                       0            0
# ...

# %%
sns.barplot(data=location)
plt.xticks(rotation=90)
plt.show()

# %%
df['5 Since How Long You are Shopping Online ?'].value_counts()
# Out:
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: 5 Since How Long You are Shopping Online ?, dtype: int64

# %%
shoppingyears=pd.crosstab(df['2 How old are you?'], df['5 Since How Long You are Shopping Online ?'])
shoppingyears
# Out:
# 5 Since How Long You are Shopping Online ?  1-2 years  2-3 years  3-4 years  \
# 2 How old are you?
# 21-30 years                                         7         16         16
# 31-40 years                                         8          5         15
# 41-50 yaers                                         1         22         12
# 51 years and above                                  0         11          1
# Less than 20 years                                  0         11          3
#
# 5 Since How Long You are Shopping Online ?  Above 4 years  Less than 1 year
# 2 How old are you?
# 21-30 years                                            30                10
# 31-40 years                                            36                17
# 41-50 yaers                                            27                 8
# 51 years and above                                      3                 4
# Less than 20 years                                      2                 4

# %%
shoppingyears.plot(kind='bar')
plt.ylabel('5 Since How Long You are Shopping Online ?')
plt.xticks(rotation=90)
plt.show()

# %%
#6 How many times you have made an online purchase in the past 1 year?

no_ofpurch_in_year=pd.crosstab(df['6 How many times you have made an online purchase in the past 1 year?'], df['2 How old are you?'], margins=True)
no_ofpurch_in_year
# Out:
# 2 How old are you?                                  21-30 years  31-40 years  \
# 6 How many times you have made an online purcha...
# 11-20 times                                                  14           11
# 21-30 times                                                   0           10
# 31-40 times                                                  17           19
# 41 times and above                                           23           13
# 42 times and above                                            0            0
# Less than 10 times                                           25           28
# All                                                          79           81
#
# 2 How old are you?                                  41-50 yaers  \
# 6 How many times you have made an online purcha...
# 11-20 times                                                   4
# 21-30 times                                                   0
# ...

# %%
#7 How do you access the internet while shopping on-line?

# %%
df['7 How do you access the internet while shopping on-line?'].value_counts()
# Out:
# Mobile internet    142
# Wi-Fi               76
# Mobile Internet     47
# Dial-up              4
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %%
df['7 How do you access the internet while shopping on-line?'].replace('Mobile internet', 'Mobile Internet', inplace=True)
df['7 How do you access the internet while shopping on-line?'].value_counts()
# Out:
# Mobile Internet    189
# Wi-Fi               76
# Dial-up              4
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %%
sns.countplot(df['7 How do you access the internet while shopping on-line?'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#13 After first visit, how do you reach the online retail store?\t\t\t\t
#Lets check what do they prefer to reach the online retail store.

df['13 After first visit, how do you reach the online retail store?'].value_counts()
# Out:
# Search Engine      87
# Via application    86
# Direct URL         70
# E-mail             18
# Social Media        8
# Name: 13 After first visit, how do you reach the online retail store?, dtype: int64

# %%
sns.countplot(df['13 After first visit, how do you reach the online retail store?'])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#14 How much time do you explore the e- retail store before making a purchase decision?

sns.countplot(df['14 How much time do you explore the e- retail store before making a purchase decision?'])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#15 What is your preferred payment Option?
#Lets see what is customers preferred mode of payment.

sns.countplot(df['15 What is your preferred payment Option?'])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#17 Why did you abandon the “Bag”, “Shopping Cart”?
#Lets look into those who abondon the cart and the reasons behind this.

sns.countplot(df['17 Why did you abandon the “Bag”, “Shopping Cart”?'])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#18 The content on the website must be easy to read and understand
df['18 The content on the website must be easy to read and understand'].value_counts()
# Out:
# Strongly agree (5)       164
# Agree (4)                 80
# Strongly disagree (1)     18
# Indifferent (3)            7
# Name: 18 The content on the website must be easy to read and understand, dtype: int64

# %%
for i in df.columns[17:47]:
    plt.title(i)
    sns.countplot(x=df[i])
    plt.xticks(rotation=90)
    plt.show()

# %%
#From the following, tick any (or all) of the online retailers you have shopped from;
df['From the following, tick any (or all) of the online retailers you have shopped from;'].value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    82
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         32
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                29
# Amazon.in, Flipkart.com, Snapdeal.com                           27
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in                                                       16
# Amazon.in, Paytm.com                                            12
# Amazon.in, Flipkart.com, Paytm.com                               7
# Name: From the following, tick any (or all) of the online retailers you have shopped from;, dtype: int64

# %%
sns.countplot(x=df['From the following, tick any (or all) of the online retailers you have shopped from;'])
plt.xticks(rotation=90)
plt.show()

# %%
for i in df.columns[47:]:
    plt.title(i)
    sns.countplot(x=df[i])
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# Amazon is the most customers preference, its easier to use, the application/website quality is very good, visually appealing website followed by Flipkart. Also the offer and variety of products are huge in Amazon and flipkart. These 2 online stores provide a very good complate and relevant product description. this will help the custemers to understand the product and its functionality. Once again Amazon stands on the top as Fast loading app among others and the reliability. Its quicker to complete the purchase from Amazon. There are several payment options at Amazon and Flipkart compared to other online stores. As per the data the product delivery is faster in Amazon and flipkart. Among the finincial privacy and security also amazon stands on the top. they give more importance to the users privacy policy. Also the online applications keep getting updated and enhanced.
#
# By this analysis we can infer that the Trust, Product quality, Service/Delivery, System quality and speed all these aspects are very important for a online store. All these factors affects the customer satisfaction.
